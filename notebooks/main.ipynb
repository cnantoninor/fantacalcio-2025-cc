# %%
import sys
sys.path.append('../')

from antoninorau.fantacalcio import FantacalcioRecommender

# Initialize the system
recommender = FantacalcioRecommender()

# Generate complete recommendations
results = recommender.run_complete_analysis(
    budget=500,
    risk_tolerance=0.7,
    save_results=True
)

# View recommendations
print(results['recommendations'])
# Out:
# WARNING:antoninorau.fantacalcio.fantacalcio_recommender:No historical data provided. Using sample data for opponent modeling.
# INFO:antoninorau.fantacalcio.phase3_opponent_modeling:Analyzed historical data across 4 positions
# INFO:antoninorau.fantacalcio.phase3_opponent_modeling:Created profiles for 5 opponents
# INFO:antoninorau.fantacalcio.phase3_opponent_modeling:Market model trained with R² score: 0.947
# INFO:antoninorau.fantacalcio.phase3_opponent_modeling:OpponentModeler initialized with 36 historical auctions
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Starting complete Fantacalcio analysis...
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Phase 1: Collecting player data...
# INFO:antoninorau.fantacalcio.phase1_data_collection:Processing season 2024-25
# INFO:antoninorau.fantacalcio.phase1_data_collection:Scraping Fantacalcio stats for season 2024-25
# INFO:antoninorau.fantacalcio.phase1_data_collection:Scraping FBref stats for Serie-A 2024-2025
# ERROR:antoninorau.fantacalcio.phase1_data_collection:Error scraping FBref stats: 403 Client Error: Forbidden for url: https://fbref.com/en/comps/11/2024-2025/stats/2024-2025-Serie-A-Stats
# INFO:antoninorau.fantacalcio.phase1_data_collection:Processing season 2023-24
# INFO:antoninorau.fantacalcio.phase1_data_collection:Scraping Fantacalcio stats for season 2023-24
# INFO:antoninorau.fantacalcio.phase1_data_collection:Scraping FBref stats for Serie-A 2023-2024
# ERROR:antoninorau.fantacalcio.phase1_data_collection:Error scraping FBref stats: 403 Client Error: Forbidden for url: https://fbref.com/en/comps/11/2023-2024/stats/2023-2024-Serie-A-Stats
# INFO:antoninorau.fantacalcio.phase1_data_collection:Processing season 2022-23
# INFO:antoninorau.fantacalcio.phase1_data_collection:Scraping Fantacalcio stats for season 2022-23
# INFO:antoninorau.fantacalcio.phase1_data_collection:Scraping FBref stats for Serie-A 2022-2023
# ERROR:antoninorau.fantacalcio.phase1_data_collection:Error scraping FBref stats: 403 Client Error: Forbidden for url: https://fbref.com/en/comps/11/2022-2023/stats/2022-2023-Serie-A-Stats
# WARNING:antoninorau.fantacalcio.fantacalcio_recommender:No data collected from web sources. Using sample data.
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Data collection complete. 141 player records collected.
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Phase 2: Generating performance predictions...
# INFO:antoninorau.fantacalcio.phase2_performance_prediction:Starting feature engineering
# ERROR:antoninorau.fantacalcio.fantacalcio_recommender:Error generating predictions: 'season_numeric'
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Phase 4: Generating final bid recommendations...
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:Starting bid optimization process
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:Prepared optimization data for 47 players
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:Added optimization constraints
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:Created optimization problem with 47 players
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:Solving optimization problem...
# WARNING:antoninorau.fantacalcio.phase4_bid_optimization:Optimization status: Infeasible
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:Creating fallback solution using greedy approach
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:
# === BID OPTIMIZATION SUMMARY ===
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:Total players selected: 9
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:Position breakdown: {'DF': 6, 'GK': 3}
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:Total budget allocated: 480.0/500
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:Expected total fantasy score: 1702.4
# INFO:antoninorau.fantacalcio.phase4_bid_optimization:Average win probability: 0.11
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Final recommendations generated for 9 players
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Saving analysis results...
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Saved player_data to fantacalcio_player_data.csv
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Saved predictions to fantacalcio_predictions.csv
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Saved market_analysis to fantacalcio_market_analysis.csv
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Saved recommendations to fantacalcio_recommendations.csv
# INFO:antoninorau.fantacalcio.fantacalcio_recommender:Saved opponent_summary to fantacalcio_opponent_summary.csv
# ============================================================
# FANTACALCIO AI RECOMMENDATION SUMMARY
# ============================================================
#
# 📋 RECOMMENDED TEAM COMPOSITION:
#           Count  Total_Bid  Expected_Score
# position
# DF            6        330          1173.3
# GK            3        150           529.1
#
# 💰 BUDGET ANALYSIS:
# Total Budget Used: 480.0/500 (96.0%)
# Budget Remaining: 20.0
#
# ⭐ TOP RECOMMENDATIONS BY POSITION:
# GK: Provedel (Bid: 50, Score: 186.6)
# DF: Spinazzola (Bid: 55, Score: 202.5)
#
# ⚠️  RISK ANALYSIS:
# Medium Risk Players: 9
#
# Average Win Probability: 10.9%
# Expected Total Fantasy Score: 1702.4
#
# ============================================================
# 🚀 Good luck with your Fantacalcio auction!
# ============================================================
#       player_name position  predicted_fantasy_score  recommended_bid  \
# 0        Provedel       GK                    186.6               50
# 1           Meret       GK                    173.4               50
# 2      Handanovic       GK                    169.1               50
# 7      Spinazzola       DF                    202.5               55
# 4        Skriniar       DF                    199.5               55
# 8  Theo Hernandez       DF                    199.2               55
# 5        Hateboer       DF                    198.2               55
# 6       Kolasinac       DF                    197.2               55
# 3          Tomori       DF                    176.7               55
#
#    estimated_market_price  win_probability  expected_value  value_efficiency  \
# 0               47.285495             0.14          26.124          0.552474
# 1               47.285495             0.15          26.010          0.550063
# 2               47.285495             0.15          25.365          0.536422
# 7               52.258595             0.08          16.200          0.309997
# 4               52.258595             0.09          17.955          0.343580
# 8               52.258595             0.08          15.936          0.304945
# 5               52.258595             0.09          17.838          0.341341
# 6               52.258595             0.09          17.748          0.339619
# 3               52.258595             0.11          19.437          0.371939
#
#    bid_vs_market risk_level     alternatives
# 0       1.057407     Medium  Perin, Szczesny
# 1       1.057407     Medium  Perin, Szczesny
# 2       1.057407     Medium  Perin, Szczesny
# 7       1.052458     Medium  Dimarco, Udogie
# 4       1.052458     Medium  Dimarco, Udogie
# 8       1.052458     Medium  Dimarco, Udogie
# 5       1.052458     Medium  Dimarco, Udogie
# 6       1.052458     Medium  Dimarco, Udogie
# 3       1.052458     Medium  Dimarco, Udogie
